# %%
import pandas as pd
import numpy as np
import sys

# %%
raw_comments_filename = 'raw_data/youtube_comments.tsv.gz'
raw_video_metadata_filename = 'raw_data/yt_metadata_en.jsonl.gz'

# %% [markdown]
# Since we are studying youtube users, we choose to start the data sampling from them.
#
# What we do is recover a fixed number of users, let's say around 1 million on carry on our analysis on the video they commented on. We assume that with enough users, we will have a large enough sample of videos to be representative of all the videos.
#
# Furthermore, we can take the first chunk of the comment file since the user are ordered in a random way. (**VERIFY THIS INFO, MAYBE IT IS ONLY IN CHRONOLOGICAL ORDER**)

# %%
chunksize = 12e6 + 1    # add one so we have a nice round number because we remove the last user 

# get one chunk of comments to recover num_users
for df_comments in pd.read_csv(raw_comments_filename, sep='\t', chunksize=chunksize, compression='infer'):
    
    # Since the last author could be cutoff, we remove the last author
    df_comments = df_comments[df_comments.author != df_comments.iloc[-1]['author']]

    print('Number of users: %d' % len(df_comments.author.unique()))        # should bebetween 500 000 and 1 million

    df_comments.to_feather('comments.feather')

    break
# Out:
# Number of users: 619701

# %%
df_comments.head()
# Out:
#    author     video_id  likes  replies
# 0       1  Gkb1QMHrGvA      2        0
# 1       1  CNtp0xqoods      0        0
# 2       1  249EEzQmVmQ      1        0
# 3       1  _U443T2K_Bs      0        0
# 4       1  rJbjhm0weYc      0        0

# %%
# Get unique video ids
video_ids = pd.DataFrame({'video_id': df_comments['video_id'].unique()})
print('Number of videos: %d' % len(video_ids))
# Out:
# Number of videos: 4136765

# %%
# clear memory before handling more data
print('Cleared %d bytes of memory' % sys.getsizeof(df_comments))
# %xdel df_comments
# Out:
# Cleared 1199999816 bytes of memory

# %% [markdown]
# After gathering our user and identifying what videos they commented on, we recover metadata on these video for our analysis by computing the intersection chunkwize of the total video set and the videos our sample of user have commented on.

# %%
# They are around 73M videos in this file
chunksize = 500e3
max_num_chunk = 74e6 // chunksize

# Define dtypes to have to most memory optimization possible
# After some tests, using dtypes seems to be a little bit beneficial
# One chunk:  
#   - without dtypes:
#       time: 32.7s
#       space: 62574070 B
#   - with dtypes
#       time: 29.8s
#       space: 56003766 B

dtype = {
    'title': str,
    'display_id': str,
    'description': str,
    'categories': 'category',
    'crawl_date': str,
    'upload_date': str,
    'dislike_count': int,
    'like_count': int,
    'duration': int,
    'view_count': int,
    'tags': object,
}

dfs = []
chunk_num = 1
for chunk in pd.read_json(raw_video_metadata_filename, dtype=dtype, chunksize=chunksize, lines=True):

    # remove unused fields for space optimizations: title, description, crawldate
    chunk.drop(['title', 'description', 'crawl_date'], axis=1 , inplace=True)

    # keep only videos where one of our user in our user pool commented
    # then remove redudant column display_id
    chunk = pd.merge(chunk, video_ids, left_on='display_id', right_on='video_id').drop('display_id', axis=1)

    print('Chunk %d out of %d. Kept %d out of %d videos.' % (chunk_num, max_num_chunk, len(chunk), chunksize))

    dfs.append(chunk)

    chunk_num += 1
    

videos_metadata = pd.concat(dfs).reset_index(drop=True)

# Save videoset
videos_metadata.to_feather('video_metadata.feather')
# Out:
# Chunk 1 out of 148. Kept 34962 out of 500000 videos.
# Chunk 2 out of 148. Kept 26111 out of 500000 videos.
# Chunk 3 out of 148. Kept 33473 out of 500000 videos.
# Chunk 4 out of 148. Kept 28317 out of 500000 videos.
# Chunk 113 out of 148. Kept 24610 out of 500000 videos.
# Chunk 114 out of 148. Kept 23896 out of 500000 videos.
# Chunk 115 out of 148. Kept 29799 out of 500000 videos.
# Chunk 116 out of 148. Kept 29932 out of 500000 videos.
# Chunk 117 out of 148. Kept 25603 out of 500000 videos.
# Chunk 118 out of 148. Kept 21777 out of 500000 videos.
# Chunk 119 out of 148. Kept 36010 out of 500000 videos.
# Chunk 120 out of 148. Kept 31559 out of 500000 videos.
# Chunk 121 out of 148. Kept 27622 out of 500000 videos.
# Chunk 122 out of 148. Kept 25097 out of 500000 videos.
# Chunk 123 out of 148. Kept 24604 out of 500000 videos.
# Chunk 124 out of 148. Kept 20715 out of 500000 videos.
# Chunk 125 out of 148. Kept 27276 out of 500000 videos.
# Chunk 126 out of 148. Kept 31034 out of 500000 videos.
# Chunk 127 out of 148. Kept 32276 out of 500000 videos.
# Chunk 128 out of 148. Kept 29715 out of 500000 videos.
# Chunk 129 out of 148. Kept 19481 out of 500000 videos.
# Chunk 130 out of 148. Kept 30746 out of 500000 videos.
# Chunk 131 out of 148. Kept 28743 out of 500000 videos.
# Chunk 132 out of 148. Kept 32484 out of 500000 videos.
# Chunk 133 out of 148. Kept 29759 out of 500000 videos.
# Chunk 134 out of 148. Kept 28257 out of 500000 videos.
# Chunk 135 out of 148. Kept 42070 out of 500000 videos.
# Chunk 136 out of 148. Kept 31903 out of 500000 videos.
# Chunk 137 out of 148. Kept 29934 out of 500000 videos.
# Chunk 138 out of 148. Kept 25425 out of 500000 videos.
# Chunk 139 out of 148. Kept 33649 out of 500000 videos.
# Chunk 140 out of 148. Kept 33552 out of 500000 videos.
# Chunk 141 out of 148. Kept 24745 out of 500000 videos.
# Chunk 142 out of 148. Kept 24877 out of 500000 videos.
# Chunk 143 out of 148. Kept 26567 out of 500000 videos.
# Chunk 144 out of 148. Kept 31608 out of 500000 videos.
# Chunk 145 out of 148. Kept 20347 out of 500000 videos.
# Chunk 146 out of 148. Kept 25968 out of 500000 videos.

# %%
videos_metadata.head()
# Out:
#          categories                channel_id  dislike_count  duration  \
# 0            Gaming  UCzWrhkg9eK5I8Bm3HfV-unA        11423.0      1762
# 1            Gaming  UCzWrhkg9eK5I8Bm3HfV-unA         1561.0      1146
# 2            Gaming  UCzWrhkg9eK5I8Bm3HfV-unA          206.0      1706
# 3            Gaming  UCzWrhkg9eK5I8Bm3HfV-unA          799.0      2146
# 4  Film & Animation  UCzWrhkg9eK5I8Bm3HfV-unA         2548.0      2196
#
#    like_count                                               tags  \
# 0     29891.0  lego city police for kids,lego polizi,lego mov...
# 1      6118.0  lego dinosaurs,lego jurassic world,lego dinosa...
# 2      2235.0  lego marvel super heroes 2,lego super heroes 2...
# 3      2501.0  lego dinosaurs,lego jurassic world,lego t-rex,...
# 4      8780.0  lego batman movie,the batman movie,new batman ...
#
#            upload_date  view_count     video_id
# 0  2017-12-08 00:00:00  23152662.0  mp9gt45aHxY
# 1  2017-12-07 00:00:00   4028426.0  hn2zYwqSINY
# 2  2017-11-18 00:00:00    585746.0  UTZLSHaE4Sw
# 3  2017-02-21 00:00:00   1547805.0  SWZG-ba1qDk
# 4  2017-02-13 00:00:00   6674760.0  3vQK78eUg2A
